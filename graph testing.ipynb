# %%
import snappy
import networkx as nx
from knot_graphs import *
from khovanov import *

import pdb

# %% [markdown]
# ### TODO - fix edge labels drawing opposite their edge for node pairs with only a single edge between them

# %%
draw_adjacency_graph(snappy.Link('4_1'), rad_increment=0.15, head_pos=0.01, tail_pos=0.99)
# Out:
# ['arc3,rad=-0.15', 'arc3,rad=0', 'arc3,rad=-0.15', 'arc3,rad=0', 'arc3,rad=-0.15', 'arc3,rad=0', 'arc3,rad=-0.15', 'arc3,rad=0']
# {(0, 1, 0): -0.15, (0, 3, 0): 0, (1, 0, 0): -0.15, (1, 2, 0): 0, (2, 3, 0): -0.15, (2, 0, 0): 0, (3, 2, 0): -0.15, (3, 1, 0): 0}

# %%
draw_adjacency_graph(snappy.Link('4_1'),
                     rad_increment=0.15, head_pos=0.2, tail_pos=0.8)
# Out:
# ['arc3,rad=-0.15', 'arc3,rad=0', 'arc3,rad=-0.15', 'arc3,rad=0', 'arc3,rad=-0.15', 'arc3,rad=0', 'arc3,rad=-0.15', 'arc3,rad=0']
# {(0, 1, 0): -0.15, (0, 3, 0): 0, (1, 0, 0): -0.15, (1, 2, 0): 0, (2, 3, 0): -0.15, (2, 0, 0): 0, (3, 2, 0): -0.15, (3, 1, 0): 0}

# %%
draw_adjacency_graph(snappy.Link('4_1'), rad_increment=0.15, head_pos=0, tail_pos=1)
# Out:
# ['arc3,rad=-0.15', 'arc3,rad=0', 'arc3,rad=-0.15', 'arc3,rad=0', 'arc3,rad=-0.15', 'arc3,rad=0', 'arc3,rad=-0.15', 'arc3,rad=0']
# {(0, 1, 0): -0.15, (0, 3, 0): 0, (1, 0, 0): -0.15, (1, 2, 0): 0, (2, 3, 0): -0.15, (2, 0, 0): 0, (3, 2, 0): -0.15, (3, 1, 0): 0}

# %%
draw_adjacency_graph(snappy.Link('3_1'), head_pos=0, tail_pos=1)
# Out:
# ['arc3,rad=-0.15', 'arc3,rad=0.15', 'arc3,rad=-0.15', 'arc3,rad=0.15', 'arc3,rad=-0.15', 'arc3,rad=0.15']
# {(0, 1, 0): -0.15, (0, 1, 1): 0.15, (1, 2, 0): -0.15, (1, 2, 1): 0.15, (2, 0, 0): -0.15, (2, 0, 1): 0.15}

# %%
draw_adjacency_graph(snappy.Link('3_1'))
# Out:
# ['arc3,rad=-0.15', 'arc3,rad=0.15', 'arc3,rad=-0.15', 'arc3,rad=0.15', 'arc3,rad=-0.15', 'arc3,rad=0.15']
# {(0, 1, 0): -0.15, (0, 1, 1): 0.15, (1, 2, 0): -0.15, (1, 2, 1): 0.15, (2, 0, 0): -0.15, (2, 0, 1): 0.15}
